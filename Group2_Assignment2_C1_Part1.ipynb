# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("customers.csv")
data
# Out:
#          ID  Year_Birth   Education Marital_Status    Income  Kidhome  \
# 0         0        1985  Graduation        Married   70951.0        0
# 1         1        1961  Graduation         Single   57091.0        0
# 2         9        1975      Master         Single   46098.0        1
# 3        13        1947         PhD          Widow   25358.0        0
# 4        17        1971         PhD        Married   60491.0        0
# ...     ...         ...         ...            ...       ...      ...
# 2235  11178        1972      Master         Single   42394.0        1
# 2236  11181        1949         PhD        Married  156924.0        0
# 2237  11187        1978       Basic         Single   26487.0        1
# 2238  11188        1957  Graduation       Together   26091.0        1
# 2239  11191        1986  Graduation       Divorced   41411.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntMeatProducts  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2206 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
data.isna().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 34
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Complain                0
# dtype: int64

# %% [markdown]
# ## **Part 1**

# %% [markdown]
# #### *Question 1.1*

# %%
#SETUP for later CHECK. Create a mask in which we store the rows that have null Income values
mask = data["Income"].isnull()
data[mask]
# Out:
#          ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 47      241        1952  Graduation       Together     NaN        0         0
# 96      498        1970  Graduation         Single     NaN        1         0
# 257    1295        1963  Graduation        Married     NaN        0         1
# 324    1612        1981         PhD         Single     NaN        1         0
# 393    1994        1983  Graduation        Married     NaN        1         0
# 478    2437        1989  Graduation        Married     NaN        0         0
# 566    2863        1970  Graduation         Single     NaN        1         2
# 578    2902        1958  Graduation       Together     NaN        1         1
# 628    3117        1955  Graduation         Single     NaN        0         1
# 756    3769        1972         PhD       Together     NaN        1         0
# 873    4345        1964    2n Cycle         Single     NaN        1         1
# ...

# %%
#CHECKING the mean incomes before insertion first
data.groupby(['Education', 'Marital_Status'])['Income'].mean().round(2)
# Out:
# Education   Marital_Status
# 2n Cycle    Divorced          49395.13
#             Married           46201.10
#             Single            53673.94
#             Together          44480.33
#             Widow             51392.20
# Basic       Divorced           9548.00
#             Married           21960.50
#             Single            18238.67
#             Together          21240.07
#             Widow             22123.00
# Graduation  Absurd            79244.00
#             Alone             34176.00
#             Divorced          54526.04
#             Married           50765.93
#             Single            51409.15
#             Together          55705.78
#             Widow             54976.66
# Master      Absurd            65487.00
#             Alone             61331.00
#             Divorced          50331.95
#             Married           53286.03
#             Single            53530.56
#             Together          52156.11
# ...

# %%
# The inserted income is rounded to 2 decimal points, which is the most reasonable format for financial values
data['Income'] = data['Income'].fillna(data.groupby(['Education', 'Marital_Status'])['Income'].transform('mean')).round(2)

# %%
#CHECK. Show the same rows that were previously null, and check that their new Income values are the correct ones
data[mask]
# Out:
#          ID  Year_Birth   Education Marital_Status    Income  Kidhome  \
# 47      241        1952  Graduation       Together  55705.78        0
# 96      498        1970  Graduation         Single  51409.15        1
# 257    1295        1963  Graduation        Married  50765.93        0
# 324    1612        1981         PhD         Single  53314.61        1
# 393    1994        1983  Graduation        Married  50765.93        1
# 478    2437        1989  Graduation        Married  50765.93        0
# 566    2863        1970  Graduation         Single  51409.15        1
# 578    2902        1958  Graduation       Together  55705.78        1
# 628    3117        1955  Graduation         Single  51409.15        0
# 756    3769        1972         PhD       Together  56095.10        1
# 873    4345        1964    2n Cycle         Single  53673.94        1
# 1028   5079        1971  Graduation        Married  50765.93        1
# ...

# %%
# CHECKING that there are no longer any nulls in Income
data.isna().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Complain               0
# dtype: int64

# %% [markdown]
# #### *Question 1.2*

# %%
data['DaysSinceEnrollment'] = (pd.to_datetime('2017-01-01') - pd.to_datetime(data['Dt_Customer'])) / np.timedelta64(1, 'D')
data['DaysSinceEnrollment'] = data['DaysSinceEnrollment'].astype(int)
data[['Dt_Customer','DaysSinceEnrollment']]
# Out:
#      Dt_Customer  DaysSinceEnrollment
# 0     2013-05-04                 1338
# 1     2014-06-15                  931
# 2     2012-08-18                 1597
# 3     2013-07-22                 1259
# 4     2013-09-06                 1213
# ...          ...                  ...
# 2235  2014-03-23                 1015
# 2236  2013-08-29                 1221
# 2237  2013-05-20                 1322
# 2238  2014-02-25                 1041
# 2239  2013-12-07                 1121
#
# [2240 rows x 2 columns]

# %%
# CHECKING that data type of the new column is int64
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# #### *Question 1.3*

# %%
def get_generation(year):
    if year >= 1981:
        return 'Millenial'
    elif year >= 1965:
        return 'GenX'
    elif year >= 1946:
        return 'BabyBoomer'
    elif year >= 1928:
        return 'Silent'

data['Generation'] = data['Year_Birth'].apply(get_generation)

# We need to exclude the people born before 1928:
data = data[data['Generation'].notnull()]

print(data[['Year_Birth', 'Generation']])
# Out:
#       Year_Birth  Generation
# 0           1985   Millenial
# 1           1961  BabyBoomer
# 2           1975        GenX
# 3           1947  BabyBoomer
# 4           1971        GenX
# ...          ...         ...
# 2235        1972        GenX
# 2236        1949  BabyBoomer
# 2237        1978        GenX
# 2238        1957  BabyBoomer
# 2239        1986   Millenial
#
# [2237 rows x 2 columns]

# %%
# We need to exclude the people born before 1928:
data = data[data['Generation'].notnull()]

print(data[['Year_Birth', 'Generation']])
# Out:
#       Year_Birth  Generation
# 0           1985   Millenial
# 1           1961  BabyBoomer
# 2           1975        GenX
# 3           1947  BabyBoomer
# 4           1971        GenX
# ...          ...         ...
# 2235        1972        GenX
# 2236        1949  BabyBoomer
# 2237        1978        GenX
# 2238        1957  BabyBoomer
# 2239        1986   Millenial
#
# [2237 rows x 2 columns]

# %% [markdown]
# #### *Question 1.4*

# %%
data = data.sort_values(by=['ID'], ascending=False)
data
# Out:
#          ID  Year_Birth   Education Marital_Status    Income  Kidhome  \
# 2239  11191        1986  Graduation       Divorced   41411.0        0
# 2238  11188        1957  Graduation       Together   26091.0        1
# 2237  11187        1978       Basic         Single   26487.0        1
# 2236  11181        1949         PhD        Married  156924.0        0
# 2235  11178        1972      Master         Single   42394.0        1
# ...     ...         ...         ...            ...       ...      ...
# 4        17        1971         PhD        Married   60491.0        0
# 3        13        1947         PhD          Widow   25358.0        0
# 2         9        1975      Master         Single   46098.0        1
# 1         1        1961  Graduation         Single   57091.0        0
# 0         0        1985  Graduation        Married   70951.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntSweetProducts  \
# ...

# %%
data.to_csv("Group2_Assignment2_C1_Part1.csv",index=False, sep=',')
